# %%
import numpy as np
import glob

import torch
import torch.nn as nn

import matplotlib.pyplot as plt

from Utils.PTModel.Models import VGLCLSTMModel

MODELNAME = "VGCLLSTM"

# %%
import Utils.fastnumpyio as fnp

def TrainModelFromFiles(batchPaths, epochs, batchSize):

    device = "cuda" if torch.cuda.is_available() else "cpu"

    model = VGLCLSTMModel()
    optimizer = torch.optim.RMSprop(model.parameters(), lr=0.1, eps=1e-7)
    #optimizer = torch.optim.Adam(model.parameters(), lr=0.01, eps=1e-7)

    criterion = nn.MSELoss()

    model.to(device)
    model.train()

    losses = []

    for i in range(epochs):

        losses.append([])

        for t in range(0, len(batchPaths)//2, 4):
            print(t)
            print(batchPaths[t:t+4])

            xTrain = fnp.load(batchPaths[t+1])
            xTrainTargetIn = fnp.load(batchPaths[t+2])
            yTrain = fnp.load(batchPaths[t+3])
            columnRef = fnp.load(batchPaths[t])

            for j in range(0, xTrain.shape[0], batchSize):

                xTrain = xTrain.reshape(xTrain.shape[0], xTrain.shape[1], 1)
                xTrainTargetIn = xTrainTargetIn.reshape(xTrainTargetIn.shape[0], xTrainTargetIn.shape[1], 1)
                yTrain = yTrain.reshape(yTrain.shape[0], yTrain.shape[1], 1)
                
                xTrainTensor = torch.tensor(xTrain[j:j+batchSize], dtype=torch.float32).to(device)
                xTrainTargetInTensor = torch.tensor(xTrainTargetIn[j:j+batchSize], dtype=torch.float32).to(device)

                yTrainTensor = torch.tensor(yTrain[j:j+batchSize], dtype=torch.float32).to(device)

                columnRefTensor = torch.tensor(columnRef[j:j+batchSize], dtype=torch.float32).to(device)

                # print(xTrainTensor.shape)
                # print(xTrainTargetInTensor.shape)
                # print(yTrainTensor.shape)
                # print(columnRefTensor.shape)

                #print(f"xTrain size: {xTrainTensor.size()}")

                yPred = model(xTrainTensor, xTrainTargetInTensor, columnRefTensor)
                
                #print(f"yPred size: {yPred.size()}")
                #print(f"yTruth size: {yTrainTensor.size()}")
                loss = criterion(yPred, yTrainTensor)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                losses[i].append(loss.cpu().detach().item())

            print(f"Epoch {i} Batch {t}: loss {losses[i][-1]}")

        print(f"Epoch {i}: loss {sum(losses[i])/len(losses[i])}")
    
    return model

# %%
model = TrainModelFromFiles(sorted(glob.glob(f"lrVGCLLSTMData/*")), 20, 32)
# Out:
# 0
# ['lrVGCLLSTMData/batch0columnRef.npy', 'lrVGCLLSTMData/batch0xTrain.npy', 'lrVGCLLSTMData/batch0xTrainTargetIn.npy', 'lrVGCLLSTMData/batch0yTrain.npy']
# Epoch 0 Batch 0: loss 1.9039191007614136
# 4
# ['lrVGCLLSTMData/batch10columnRef.npy', 'lrVGCLLSTMData/batch10xTrain.npy', 'lrVGCLLSTMData/batch10xTrainTargetIn.npy', 'lrVGCLLSTMData/batch10yTrain.npy']
# Epoch 0 Batch 4: loss 10.220907211303711
# 8
# ['lrVGCLLSTMData/batch11columnRef.npy', 'lrVGCLLSTMData/batch11xTrain.npy', 'lrVGCLLSTMData/batch11xTrainTargetIn.npy', 'lrVGCLLSTMData/batch11yTrain.npy']
# Epoch 0 Batch 8: loss 8.978261947631836
# 12
# ['lrVGCLLSTMData/batch12columnRef.npy', 'lrVGCLLSTMData/batch12xTrain.npy', 'lrVGCLLSTMData/batch12xTrainTargetIn.npy', 'lrVGCLLSTMData/batch12yTrain.npy']
# Epoch 0 Batch 12: loss 8.088552474975586
# 16
# ['lrVGCLLSTMData/batch13columnRef.npy', 'lrVGCLLSTMData/batch13xTrain.npy', 'lrVGCLLSTMData/batch13xTrainTargetIn.npy', 'lrVGCLLSTMData/batch13yTrain.npy']
# Epoch 0 Batch 16: loss 10.442082405090332
# 20
# ['lrVGCLLSTMData/batch14columnRef.npy', 'lrVGCLLSTMData/batch14xTrain.npy', 'lrVGCLLSTMData/batch14xTrainTargetIn.npy', 'lrVGCLLSTMData/batch14yTrain.npy']
# Epoch 0 Batch 20: loss 19.396312713623047
# 24
# ['lrVGCLLSTMData/batch15columnRef.npy', 'lrVGCLLSTMData/batch15xTrain.npy', 'lrVGCLLSTMData/batch15xTrainTargetIn.npy', 'lrVGCLLSTMData/batch15yTrain.npy']
# Epoch 0 Batch 24: loss 9.602476119995117
# 28
# ['lrVGCLLSTMData/batch16columnRef.npy', 'lrVGCLLSTMData/batch16xTrain.npy', 'lrVGCLLSTMData/batch16xTrainTargetIn.npy', 'lrVGCLLSTMData/batch16yTrain.npy']
# Epoch 0 Batch 28: loss 10.619196891784668
# 32
# ['lrVGCLLSTMData/batch17columnRef.npy', 'lrVGCLLSTMData/batch17xTrain.npy', 'lrVGCLLSTMData/batch17xTrainTargetIn.npy', 'lrVGCLLSTMData/batch17yTrain.npy']
# Epoch 0 Batch 32: loss 9.260293960571289
# 36
# ['lrVGCLLSTMData/batch18columnRef.npy', 'lrVGCLLSTMData/batch18xTrain.npy', 'lrVGCLLSTMData/batch18xTrainTargetIn.npy', 'lrVGCLLSTMData/batch18yTrain.npy']
# Epoch 0 Batch 36: loss 6.644974708557129
# 40
# ['lrVGCLLSTMData/batch19columnRef.npy', 'lrVGCLLSTMData/batch19xTrain.npy', 'lrVGCLLSTMData/batch19xTrainTargetIn.npy', 'lrVGCLLSTMData/batch19yTrain.npy']
# Epoch 0 Batch 40: loss 10.525435447692871
# 44
# ['lrVGCLLSTMData/batch1columnRef.npy', 'lrVGCLLSTMData/batch1xTrain.npy', 'lrVGCLLSTMData/batch1xTrainTargetIn.npy', 'lrVGCLLSTMData/batch1yTrain.npy']
# Epoch 0 Batch 44: loss 14.258864402770996
# 48
# ['lrVGCLLSTMData/batch20columnRef.npy', 'lrVGCLLSTMData/batch20xTrain.npy', 'lrVGCLLSTMData/batch20xTrainTargetIn.npy', 'lrVGCLLSTMData/batch20yTrain.npy']
# Epoch 0 Batch 48: loss 5.56806755065918
# Epoch 0: loss 9.812940461191571
# 0
# ['lrVGCLLSTMData/batch0columnRef.npy', 'lrVGCLLSTMData/batch0xTrain.npy', 'lrVGCLLSTMData/batch0xTrainTargetIn.npy', 'lrVGCLLSTMData/batch0yTrain.npy']
# Epoch 1 Batch 0: loss 1.8399205207824707
# 4
# ['lrVGCLLSTMData/batch10columnRef.npy', 'lrVGCLLSTMData/batch10xTrain.npy', 'lrVGCLLSTMData/batch10xTrainTargetIn.npy', 'lrVGCLLSTMData/batch10yTrain.npy']
# Epoch 1 Batch 4: loss 10.19227123260498
# 8
# ['lrVGCLLSTMData/batch11columnRef.npy', 'lrVGCLLSTMData/batch11xTrain.npy', 'lrVGCLLSTMData/batch11xTrainTargetIn.npy', 'lrVGCLLSTMData/batch11yTrain.npy']
# Epoch 1 Batch 8: loss 8.948437690734863
# 12
# ['lrVGCLLSTMData/batch12columnRef.npy', 'lrVGCLLSTMData/batch12xTrain.npy', 'lrVGCLLSTMData/batch12xTrainTargetIn.npy', 'lrVGCLLSTMData/batch12yTrain.npy']
# Epoch 1 Batch 12: loss 8.063650131225586
# 16
# ['lrVGCLLSTMData/batch13columnRef.npy', 'lrVGCLLSTMData/batch13xTrain.npy', 'lrVGCLLSTMData/batch13xTrainTargetIn.npy', 'lrVGCLLSTMData/batch13yTrain.npy']
# Epoch 1 Batch 16: loss 10.422647476196289
# 20
# ['lrVGCLLSTMData/batch14columnRef.npy', 'lrVGCLLSTMData/batch14xTrain.npy', 'lrVGCLLSTMData/batch14xTrainTargetIn.npy', 'lrVGCLLSTMData/batch14yTrain.npy']
# Epoch 1 Batch 20: loss 19.39690399169922
# 24
# ['lrVGCLLSTMData/batch15columnRef.npy', 'lrVGCLLSTMData/batch15xTrain.npy', 'lrVGCLLSTMData/batch15xTrainTargetIn.npy', 'lrVGCLLSTMData/batch15yTrain.npy']
# Epoch 1 Batch 24: loss 9.582474708557129
# 28
# ['lrVGCLLSTMData/batch16columnRef.npy', 'lrVGCLLSTMData/batch16xTrain.npy', 'lrVGCLLSTMData/batch16xTrainTargetIn.npy', 'lrVGCLLSTMData/batch16yTrain.npy']
# Epoch 1 Batch 28: loss 10.619118690490723
# 32
# ['lrVGCLLSTMData/batch17columnRef.npy', 'lrVGCLLSTMData/batch17xTrain.npy', 'lrVGCLLSTMData/batch17xTrainTargetIn.npy', 'lrVGCLLSTMData/batch17yTrain.npy']
# Epoch 1 Batch 32: loss 9.260310173034668
# 36
# ['lrVGCLLSTMData/batch18columnRef.npy', 'lrVGCLLSTMData/batch18xTrain.npy', 'lrVGCLLSTMData/batch18xTrainTargetIn.npy', 'lrVGCLLSTMData/batch18yTrain.npy']
# Epoch 1 Batch 36: loss 6.644974708557129
# 40
# ['lrVGCLLSTMData/batch19columnRef.npy', 'lrVGCLLSTMData/batch19xTrain.npy', 'lrVGCLLSTMData/batch19xTrainTargetIn.npy', 'lrVGCLLSTMData/batch19yTrain.npy']
# Epoch 1 Batch 40: loss 10.52545166015625
# 44
# ['lrVGCLLSTMData/batch1columnRef.npy', 'lrVGCLLSTMData/batch1xTrain.npy', 'lrVGCLLSTMData/batch1xTrainTargetIn.npy', 'lrVGCLLSTMData/batch1yTrain.npy']
# Epoch 1 Batch 44: loss 14.259021759033203
# 48
# ['lrVGCLLSTMData/batch20columnRef.npy', 'lrVGCLLSTMData/batch20xTrain.npy', 'lrVGCLLSTMData/batch20xTrainTargetIn.npy', 'lrVGCLLSTMData/batch20yTrain.npy']
# Epoch 1 Batch 48: loss 5.568299293518066
# Epoch 1: loss 9.798097541216414
# 0
# ['lrVGCLLSTMData/batch0columnRef.npy', 'lrVGCLLSTMData/batch0xTrain.npy', 'lrVGCLLSTMData/batch0xTrainTargetIn.npy', 'lrVGCLLSTMData/batch0yTrain.npy']
# Epoch 2 Batch 0: loss 1.840206265449524
# 4
# ['lrVGCLLSTMData/batch10columnRef.npy', 'lrVGCLLSTMData/batch10xTrain.npy', 'lrVGCLLSTMData/batch10xTrainTargetIn.npy', 'lrVGCLLSTMData/batch10yTrain.npy']
# Epoch 2 Batch 4: loss 10.192655563354492
# 8
# ['lrVGCLLSTMData/batch11columnRef.npy', 'lrVGCLLSTMData/batch11xTrain.npy', 'lrVGCLLSTMData/batch11xTrainTargetIn.npy', 'lrVGCLLSTMData/batch11yTrain.npy']
# Epoch 2 Batch 8: loss 8.948453903198242
# 12
# ['lrVGCLLSTMData/batch12columnRef.npy', 'lrVGCLLSTMData/batch12xTrain.npy', 'lrVGCLLSTMData/batch12xTrainTargetIn.npy', 'lrVGCLLSTMData/batch12yTrain.npy']
# Epoch 2 Batch 12: loss 8.06411075592041
# 16
# ['lrVGCLLSTMData/batch13columnRef.npy', 'lrVGCLLSTMData/batch13xTrain.npy', 'lrVGCLLSTMData/batch13xTrainTargetIn.npy', 'lrVGCLLSTMData/batch13yTrain.npy']
# Epoch 2 Batch 16: loss 10.422680854797363
# 20
# ['lrVGCLLSTMData/batch14columnRef.npy', 'lrVGCLLSTMData/batch14xTrain.npy', 'lrVGCLLSTMData/batch14xTrainTargetIn.npy', 'lrVGCLLSTMData/batch14yTrain.npy']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 model = TrainModelFromFiles(sorted(glob.glob(f"lrVGCLLSTMData/*")), 20, 32)
#
# Cell In[84], line 58, in TrainModelFromFiles(batchPaths, epochs, batchSize)
#      55 loss = criterion(yPred, yTrainTensor)
#      57 optimizer.zero_grad()
# ---> 58 loss.backward()
#      59 optimizer.step()
#      61 losses[i].append(loss.cpu().detach().item())
#
# File ~/miniconda3/envs/DissEnv/lib/python3.10/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/miniconda3/envs/DissEnv/lib/python3.10/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/miniconda3/envs/DissEnv/lib/python3.10/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
torch.save(model, f"Models/{MODELNAME}/LodeRunnerLSTM.pt")

# %%
total = 0
for name, param in model.named_parameters():
    print(f"{name:<24}: {param.numel():5}")
    total += param.numel()

print(f"Total Params: {total}")
# Out:
# histLSTM.weight_ih_l0   :   512
# histLSTM.weight_hh_l0   : 65536
# histLSTM.bias_ih_l0     :   512
# histLSTM.bias_hh_l0     :   512
# colLSTM.weight_ih_l0    : 131072
# colLSTM.weight_hh_l0    : 65536
# colLSTM.bias_ih_l0      :   512
# colLSTM.bias_hh_l0      :   512
# textLSTM.weight_ih_l0   :   512
# textLSTM.weight_hh_l0   : 65536
# textLSTM.bias_ih_l0     :   512
# textLSTM.bias_hh_l0     :   512
# outputLayer.weight      :  1152
# outputLayer.bias        :     9
# Total Params: 332937
